# %% [markdown]
# # OPAL - Ordinary People Accelerating Learning

# %% [markdown]
# The following block will start the design space exploration using the config file 'example_MLP.cfg'. If there are results with the same name that already exist, then the new results will be saved as 'example_MLP_1', then 'example_MLP_2', etc.

# %%
import sys
import libOPAL.DSE 
libOPAL.DSE.run('./example_MLP.cfg')

# %% [markdown]
# The below block simply imports the code for parsing and plotting the results:

# %%
# %matplotlib notebook
from libOPAL.results import ResultsBrowser

# %% [markdown]
# The results for an example MLP design problen can then be plot as follows:

# %%
results_plot_MLP = ResultsBrowser('./results/example_MLP')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# Likewise, the same can be done for the results of an example CNN design problem:

# %%
results_plot_CNN = ResultsBrowser('./results/example_CNN')
# Out:
# <img src="data:image/png;base64,..." width="900">
