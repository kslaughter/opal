# %% [markdown]
# # OPAL - Ordinary People Accelerating Learning

# %%
# %matplotlib notebook
from libOPAL.results import ResultsBrowser
results_plot_CNN = ResultsBrowser('./results/example_CNN')
# Out:
# Using TensorFlow backend.
# <img src="data:image/png;base64,..." width="900">

# %%
results_plot_MLP = ResultsBrowser('./results/example_MLP_4')
# Out:
# <img src="data:image/png;base64,..." width="900">
